# %%
from collections import defaultdict

# %%
f = open('input\input07.txt')
rows = [row.strip().split('-> ') for row in f.readlines()]

# %%
trunks, leafs = [], []
for row in rows:
    try:
        leafslist = row[1].split(',')
        for leaf in leafslist:
            leafs.append(leaf.strip())
    except IndexError:
        pass
    trunks.append(row[0].split()[0])

# %%
set(trunks) - set(leafs)
# Out:
# {'svugo'}

# %%
##Part B

# %%
f = open('input\input07.txt')
rows = [row.strip().split() for row in f.readlines()]
trunk = 'svugo'
rows
# Out:
# [['mmqyju', '(156)', '->', 'rjzvwv,', 'noybkx'],
#  ['dvkug', '(90)', '->', 'tbjbz,', 'gxnvl'],
#  ['meeiw', '(95)'],
#  ['iaibv', '(52)'],
#  ['ckddz', '(36)'],
#  ['yikfhvr', '(52)'],
#  ['phqiqi', '(92)'],
#  ['ywctcn', '(38)'],
#  ['boofr', '(332)', '->', 'aqiun,', 'zilgfzu'],
#  ['zfusug', '(65)'],
#  ['yffcj',
#   '(90)',
#   '->',
#   'bbmmtud,',
#   'bqbgocl,',
#   'kgntkz,',
#   'mmfwbku,',
#   'asefoiu'],
#  ['velbwcl', '(432)'],
#  ['liori', '(107)', '->', 'fzcts,', 'wgfbd'],
#  ['watknc', '(96)'],
#  ['wbpvo', '(77)', '->', 'dtdkt,', 'ixhnyqi'],
#  ['mladbjo', '(27)'],
#  ['cimsvsq', '(69)'],
#  ['ugyjqg', '(10)'],
#  ['tmybiz', '(55)'],
#  ['ueheft', '(12)'],
#  ['awweagx', '(26)'],
#  ['zxiqpq', '(88)'],
#  ['atcrb', '(92)'],
#  ['ocauj', '(95)'],
#  ['ayqfub', '(306)', '->', 'drwyz,', 'prssjgo'],
#  ['xbeau', '(76)', '->', 'xxshfpr,', 'renhdd'],
#  ['tmicb', '(21)'],
#  ['uesefn', '(59)'],
#  ['kbcztr', '(82)'],
#  ['rcssnrj', '(89)'],
#  ['ruahai', '(23)'],
# ...

# %%
testcase =\
"""pbga (66)
xhth (57)
ebii (61)
havc (66)
ktlj (57)
fwft (72) -> ktlj, cntj, xhth
qoyq (66)
padx (45) -> pbga, havc, qoyq
tknk (41) -> ugml, padx, fwft
jptl (61)
ugml (68) -> gyxo, ebii, jptl
gyxo (61)
cntj (57)"""

# %%
rows = [row.strip().split() for row in testcase.split('\n')]
trunk = 'tknk'
rows
# Out:
# [['pbga', '(66)'],
#  ['xhth', '(57)'],
#  ['ebii', '(61)'],
#  ['havc', '(66)'],
#  ['ktlj', '(57)'],
#  ['fwft', '(72)', '->', 'ktlj,', 'cntj,', 'xhth'],
#  ['qoyq', '(66)'],
#  ['padx', '(45)', '->', 'pbga,', 'havc,', 'qoyq'],
#  ['tknk', '(41)', '->', 'ugml,', 'padx,', 'fwft'],
#  ['jptl', '(61)'],
#  ['ugml', '(68)', '->', 'gyxo,', 'ebii,', 'jptl'],
#  ['gyxo', '(61)'],
#  ['cntj', '(57)']]

# %%
weights = defaultdict(int)
leafs = defaultdict(list)
for row in rows:
    base, weight, *rest = row
    weights[base] = int(weight[1:-1])
    if len(rest):
        assert rest[0] == '->'
        for item in rest[1:]:
            leafs[base].append(item.strip(','))

# %%
leafs[trunk]
# Out:
# []

# %%
leafs['meeiw']
# Out:
# []

# %%
def calc_weight(part):
    
    if not len(leafs[part]):
        return weights[part]
    
    return weights[part] + sum([calc_weight(i) for i in leafs[part]])

# %%
for leaf in leafs[trunk]:
    print(leaf, calc_weight(leaf))
# Out:
# xolvnpy 64652
# gjxqx 64661
# gtzxxav 64652
# njorjq 64652
# qpiklvf 64652

# %%
for leaf in leafs['yruivis']:
    print(leaf, calc_weight(leaf))
# Out:
# oxipms 2671
# ggpau 2671
# sphbbz 2680

# %%
for leaf in leafs['sphbbz']:
    print(leaf, calc_weight(leaf))
# Out:
# gioryg 217
# scetry 217
# sfjspc 217
# ivpbt 217
# vyufo 217
# valbm 217
# oprfjt 217

# %%
weights['sphbbz'] - 9
# Out:
# 1152

# %%
base = trunk
for _ in range(10):
    w = [calc_weight(leaf) for leaf in leafs[base]]
    print(w)
    if len(set(w)) == 1:
        print('found!', base, delta)
        break
    i = w.index(max(w))
    delta = max(w) - min(w)
    base = leafs[base][i]
    print('now searching ', base)

print(base,' weight:', weights[base]-delta)
# Out:
# [64652, 64661, 64652, 64652, 64652]
# now searching  gjxqx
# [10782, 10773, 10773, 10773, 10773, 10773]
# now searching  yruivis
# [2671, 2671, 2680]
# now searching  sphbbz
# [217, 217, 217, 217, 217, 217, 217]
# found! sphbbz 9
# sphbbz  weight: 1152

# %%
leafs_set = set()
for key in leafs:
    for leaf in leafs[key]:
        leafs_set.add(leaf)

# %%
len(weights)
# Out:
# 1288

# %%
len(leafs_set)
# Out:
# 1287

# %%
set(weights) - leafs_set
# Out:
# {'svugo'}

# %%
leafs_set
# Out:
# {'fwft', 'padx', 'tknk', 'ugml'}

# %%
leafs
# Out:
# defaultdict(list,
#             {'fwft': ['ktlj', 'cntj', 'xhth'],
#              'padx': ['pbga', 'havc', 'qoyq'],
#              'tknk': ['ugml', 'padx', 'fwft'],
#              'ugml': ['gyxo', 'ebii', 'jptl']})

# %%
for key in leafs:
    print(key)
# Out:
# fwft
# padx
# tknk
# ugml
